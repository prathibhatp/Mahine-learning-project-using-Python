# %% [markdown]
# Importing all libraries and loading dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("/content/datafraud.csv")
df
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT    9839.64  C1231006815      170136.00
# 1           1   PAYMENT    1864.28  C1666544295       21249.00
# 2           1  TRANSFER     181.00  C1305486145         181.00
# 3           1  CASH_OUT     181.00   C840083671         181.00
# 4           1   PAYMENT   11668.14  C2048537720       41554.00
# ...       ...       ...        ...          ...            ...
# 1048570    95  CASH_OUT  132557.35  C1179511630      479803.00
# 1048571    95   PAYMENT    9917.36  C1956161225       90545.00
# 1048572    95   PAYMENT   14140.05  C2037964975       20545.00
# 1048573    95   PAYMENT   10020.05  C1633237354       90605.00
# 1048574    95   PAYMENT   11450.03  C1264356443       80584.95
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.tail()
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 1048570    95  CASH_OUT  132557.35  C1179511630      479803.00
# 1048571    95   PAYMENT    9917.36  C1956161225       90545.00
# 1048572    95   PAYMENT   14140.05  C2037964975       20545.00
# 1048573    95   PAYMENT   10020.05  C1633237354       90605.00
# 1048574    95   PAYMENT   11450.03  C1264356443       80584.95
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 1048570       347245.65   C435674507       484329.37       616886.72        0
# 1048571        80627.64   M668364942            0.00            0.00        0
# 1048572         6404.95  M1355182933            0.00            0.00        0
# 1048573        80584.95  M1964992463            0.00            0.00        0
# 1048574        69134.92   M677577406            0.00            0.00        0
#
#          isFlaggedFraud
# 1048570               0
# 1048571               0
# 1048572               0
# ...

# %%
df.size
# Out:
# 11534325

# %%
df.shape
# Out:
# (1048575, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   step            1048575 non-null  int64
#  1   type            1048575 non-null  object
#  2   amount          1048575 non-null  float64
#  3   nameOrig        1048575 non-null  object
#  4   oldbalanceOrg   1048575 non-null  float64
#  5   newbalanceOrig  1048575 non-null  float64
#  6   nameDest        1048575 non-null  object
#  7   oldbalanceDest  1048575 non-null  float64
#  8   newbalanceDest  1048575 non-null  float64
#  9   isFraud         1048575 non-null  int64
#  10  isFlaggedFraud  1048575 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 88.0+ MB

# %%
df['type'].value_counts()
# Out:
# CASH_OUT    373641
# PAYMENT     353873
# CASH_IN     227130
# TRANSFER     86753
# DEBIT         7178
# Name: type, dtype: int64

# %% [markdown]
# **DATA VISUALIZATION**

# %%
a=df['type'].value_counts()
plt.hist(a)
# Out:
# (array([1., 0., 1., 0., 0., 0., 1., 0., 0., 2.]),
#  array([  7178. ,  43824.3,  80470.6, 117116.9, 153763.2, 190409.5,
#         227055.8, 263702.1, 300348.4, 336994.7, 373641. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x='type', data=df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.barplot(x='type', y='amount', data=df)
# Out:
# <Axes: xlabel='type', ylabel='amount'>

# %%
correlation=df.corr()
correlation['isFraud'].sort_values(ascending=False)
# Out:
# <ipython-input-96-8282c8aac94d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
# isFraud           1.000000
# amount            0.128862
# step              0.045030
# oldbalanceOrg     0.003829
# newbalanceDest   -0.000495
# oldbalanceDest   -0.007552
# newbalanceOrig   -0.009438
# isFlaggedFraud         NaN
# Name: isFraud, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(),cmap='BrBG',fmt='.2f',linewidths=2,annot=True)
# Out:
# <ipython-input-97-efe617d6c4a1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='BrBG',fmt='.2f',linewidths=2,annot=True)
# <Axes: >

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %% [markdown]
# Encoding categorical column

# %%
dummy=pd.get_dummies(df['type'],drop_first=True)
dummy
# Out:
#          CASH_OUT  DEBIT  PAYMENT  TRANSFER
# 0               0      0        1         0
# 1               0      0        1         0
# 2               0      0        0         1
# 3               1      0        0         0
# 4               0      0        1         0
# ...           ...    ...      ...       ...
# 1048570         1      0        0         0
# 1048571         0      0        1         0
# 1048572         0      0        1         0
# 1048573         0      0        1         0
# 1048574         0      0        1         0
#
# [1048575 rows x 4 columns]

# %%
data = pd.concat([df,dummy], axis=1)
data
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT    9839.64  C1231006815      170136.00
# 1           1   PAYMENT    1864.28  C1666544295       21249.00
# 2           1  TRANSFER     181.00  C1305486145         181.00
# 3           1  CASH_OUT     181.00   C840083671         181.00
# 4           1   PAYMENT   11668.14  C2048537720       41554.00
# ...       ...       ...        ...          ...            ...
# 1048570    95  CASH_OUT  132557.35  C1179511630      479803.00
# 1048571    95   PAYMENT    9917.36  C1956161225       90545.00
# 1048572    95   PAYMENT   14140.05  C2037964975       20545.00
# 1048573    95   PAYMENT   10020.05  C1633237354       90605.00
# 1048574    95   PAYMENT   11450.03  C1264356443       80584.95
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
data=data.drop(['type'],axis=1)
data
# Out:
#          step     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1    9839.64  C1231006815      170136.00       160296.36
# 1           1    1864.28  C1666544295       21249.00        19384.72
# 2           1     181.00  C1305486145         181.00            0.00
# 3           1     181.00   C840083671         181.00            0.00
# 4           1   11668.14  C2048537720       41554.00        29885.86
# ...       ...        ...          ...            ...             ...
# 1048570    95  132557.35  C1179511630      479803.00       347245.65
# 1048571    95    9917.36  C1956161225       90545.00        80627.64
# 1048572    95   14140.05  C2037964975       20545.00         6404.95
# 1048573    95   10020.05  C1633237354       90605.00        80584.95
# 1048574    95   11450.03  C1264356443       80584.95        69134.92
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %% [markdown]
# Replacing strings from input features

# %%
data['nameOrig']=data['nameOrig'].str.replace('C','')

# %%
data['nameDest']=data['nameDest'].str.replace('C','')
data['nameDest']=data['nameDest'].str.replace('M','')

# %%
data['nameOrig']=data['nameOrig'].str.replace('null','0')
data['nameDest']=data['nameDest'].str.replace('null','0')

# %%
df.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %%
data['nameOrig']=data['nameOrig'].astype(int)

# %%
data['nameDest']=data['nameDest'].astype(int)

# %%
data.loc[data.nameDest==0,'nameDest']=np.NaN

# %%
data.loc[data.nameOrig==0,'nameOrig']=np.NaN

# %%
data['oldbalanceDest']=data['oldbalanceDest'].fillna(data['oldbalanceDest'].mean())
data['newbalanceDest']=data['newbalanceDest'].fillna(data['newbalanceDest'].mean())
data['isFraud']=data['isFraud'].fillna(data['isFraud'].mode()[0])
data['isFlaggedFraud']=data['isFlaggedFraud'].fillna(data['isFlaggedFraud'].mode()[0])

# %%
data.isnull().sum()
# Out:
# step              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# CASH_OUT          0
# DEBIT             0
# PAYMENT           0
# TRANSFER          0
# dtype: int64

# %%
x=data.drop(['isFraud'],axis=1)# X CONTAINS INPUT DATAS
x
# Out:
#          step     amount      nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1    9839.64  1.231007e+09      170136.00       160296.36
# 1           1    1864.28  1.666544e+09       21249.00        19384.72
# 2           1     181.00  1.305486e+09         181.00            0.00
# 3           1     181.00  8.400837e+08         181.00            0.00
# 4           1   11668.14  2.048538e+09       41554.00        29885.86
# ...       ...        ...           ...            ...             ...
# 1048570    95  132557.35  1.179512e+09      479803.00       347245.65
# 1048571    95    9917.36  1.956161e+09       90545.00        80627.64
# 1048572    95   14140.05  2.037965e+09       20545.00         6404.95
# 1048573    95   10020.05  1.633237e+09       90605.00        80584.95
# 1048574    95   11450.03  1.264356e+09       80584.95        69134.92
#
#              nameDest  oldbalanceDest  newbalanceDest  isFlaggedFraud  \
# ...

# %%
y=data.isFraud
y
# Out:
# 0          0
# 1          0
# 2          1
# 3          1
# 4          0
#           ..
# 1048570    0
# 1048571    0
# 1048572    0
# 1048573    0
# 1048574    0
# Name: isFraud, Length: 1048575, dtype: int64

# %% [markdown]
# Splitting of data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Model creation

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()
model.fit(x_train,y_train)
print(model.score(x_test,y_test))
# Out:
# 0.9995835624799331

# %%
from sklearn.svm import SVC
model1=SVC()
model1.fit(x_train,y_train)
print(model1.score(x_test,y_test))
# Out:
# 0.9988905595839439

# %%
from sklearn.linear_model import LogisticRegression
model2=LogisticRegression()
model2.fit(x_train,y_train)
print(model2.score(x_test,y_test))
# Out:
# 0.9989636745683832
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# Performance evaluation

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,ConfusionMatrixDisplay
report=classification_report(y_pred,y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    314227
#            1       0.81      0.82      0.81       346
#
#     accuracy                           1.00    314573
#    macro avg       0.90      0.91      0.91    314573
# weighted avg       1.00      1.00      1.00    314573

# %%
label=['fraud','nofraud']

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,ConfusionMatrixDisplay
mat=confusion_matrix(y_pred,y_test)
cmd=ConfusionMatrixDisplay(mat,display_labels=label)
cmd.plot()
mat
# Out:
# array([[314160,     67],
#        [    64,    282]])

# %%
acs=accuracy_score(y_pred,y_test)
acs
# Out:
# 0.9995835624799331
